# %%
from IPython.display import display, HTML
import os
import csv
import pandas as pd

# %%
#######
#Paths#
#######
filename = "nyctickets.csv"
output_path1 = os.path.join("Output", "cleanednyctickets_essential.csv")
output_path2 = os.path.join("Output", "cleanednyctickets_extra.csv")

# %%
df = pd.read_csv(filename, header=0, index_col=0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (18,29,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
df.head()
# Out:
#                Plate ID Registration State Plate Type  Issue Date  \
# Summons Number
# 1454437777      GPM6410                 99        PAS  01/01/2021
# 1459682567      JGJ7440                 NY        PAS  01/01/2021
# 1456168186      GVA5471                 NY        PAS  01/01/2021
# 1456655127      JLH5263                 NY        PAS  01/01/2021
# 1457203959      HXL2432                 NY        PAS  01/01/2021
#
#                 Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# Summons Number
# 1454437777                  40              SUBN        DODGE              P
# 1459682567                  98              SUBN        NISSA              P
# 1456168186                  14               P-U        CHEVR              P
# 1456655127                  98               SDN          BMW              P
# 1457203959                  98               SDN        NISSA              P
#
#                 Street Code1  Street Code2  ...  Vehicle Color  \
# ...

# %%
cleaned_df = df[["Issue Date", "Violation Code", "Vehicle Body Type", "Vehicle Make", "Street Code1", "Street Code2", "Street Code3", "Violation Location", "Violation Precinct", "Violation Time", "Issuer Precinct"]]
cleaned_df.head()
# Out:
#                 Issue Date  Violation Code Vehicle Body Type Vehicle Make  \
# Summons Number
# 1454437777      01/01/2021              40              SUBN        DODGE
# 1459682567      01/01/2021              98              SUBN        NISSA
# 1456168186      01/01/2021              14               P-U        CHEVR
# 1456655127      01/01/2021              98               SDN          BMW
# 1457203959      01/01/2021              98               SDN        NISSA
#
#                 Street Code1  Street Code2  Street Code3  Violation Location  \
# Summons Number
# 1454437777              9930          6780          6880                62.0
# 1459682567             28790          7990         50390               115.0
# 1456168186             14620         27630         12220                52.0
# 1456655127             19310         24890         10210                25.0
# 1457203959             25085         18140         18290               103.0
#
# ...

# %%
cleaned_df_extra = df[["Issue Date", "Violation Code", "Vehicle Body Type", "Vehicle Make", "Street Code1", "Street Code2", "Street Code3", "Violation Location", "Violation Precinct", "Violation Time", "Issuer Precinct", "House Number", "Street Name", "Intersecting Street", "Vehicle Color", "Vehicle Year"]]
cleaned_df_extra.head()
# Out:
#                 Issue Date  Violation Code Vehicle Body Type Vehicle Make  \
# Summons Number
# 1454437777      01/01/2021              40              SUBN        DODGE
# 1459682567      01/01/2021              98              SUBN        NISSA
# 1456168186      01/01/2021              14               P-U        CHEVR
# 1456655127      01/01/2021              98               SDN          BMW
# 1457203959      01/01/2021              98               SDN        NISSA
#
#                 Street Code1  Street Code2  Street Code3  Violation Location  \
# Summons Number
# 1454437777              9930          6780          6880                62.0
# 1459682567             28790          7990         50390               115.0
# 1456168186             14620         27630         12220                52.0
# 1456655127             19310         24890         10210                25.0
# 1457203959             25085         18140         18290               103.0
#
# ...

# %%
cleaned_df.to_csv(output_path1)

# %%
cleaned_df_extra.to_csv(output_path2)

# %%
#Car Type & Makes Into Variables
cartype = cleaned_df["Vehicle Body Type"]
carmake = cleaned_df["Vehicle Make"]

# %%
#Unique Car Types Array
uniquetypes = pd.Series(cleaned_df['Vehicle Body Type'])

# %%
uniquetypes

# %%
#Sort Entire DF by Car Type
uniquetypes2 = cleaned_df.sort_values(by=['Vehicle Body Type'])
uniquetypes2
# Out:
#                 Issue Date  Violation Code Vehicle Body Type Vehicle Make  \
# Summons Number
# 4725312060      03/10/2021              36                00        DODGE
# 4727077802      03/26/2021              36                00         FORD
# 4723908195      02/24/2021              36                00         FORD
# 4721096203      01/20/2021              36                00          GMC
# 4725921877      03/16/2021              36                00        CHEVR
# ...                    ...             ...               ...          ...
# 8567814029      03/31/2021              70               NaN          NaN
# 8571761632      03/31/2021              14               NaN          NaN
# 8817042894      03/31/2021               0               NaN          NaN
# 8939005132      03/31/2021               0               NaN          NaN
# 8948955317      03/31/2021               0               NaN          NaN
#
# ...

# %%
#Car Makes Unique Array
uniquemakes = pd.Series(carmake).unique()  
uniquemakes
# Out:
# array(['DODGE', 'NISSA', 'CHEVR', ..., 'DA/DA', 'ZHEN', 'NI/DI'],
#       dtype=object)

# %%
#Car Makes Series
uniquemakes = pd.Series(carmake).unique()  
uniquemakes

# %%
#Sort Entire DF by Car Make
uniquemakes2 = cleaned_df.sort_values(by=['Vehicle Make'])
uniquemakes2
# Out:
#                 Issue Date  Violation Code Vehicle Body Type Vehicle Make  \
# Summons Number
# 1482256022      03/05/2021              21              SUBN         ACUR
# 1474323790      03/20/2021              98              SUBN         ACUR
# 1481748853      01/08/2021              21               SDN         ACUR
# 1482789073      03/15/2021              21               SDN         ACUR
# 1473168661      02/27/2021              53               SDN         ACUR
# ...                    ...             ...               ...          ...
# 8977301520      03/31/2021              38               VAN          NaN
# 8986808092      03/31/2021              77               BUS          NaN
# 8982753333      03/31/2021              19              SUBN          NaN
# 8994504746      03/31/2021              40              UTIL          NaN
# 8993203118      03/31/2021              14              REFG          NaN
#
# ...

# %%
makes_series = pd.Series(cleaned_df['Vehicle Make'])  
makes_series
# Out:
# Summons Number
# 1454437777    DODGE
# 1459682567    NISSA
# 1456168186    CHEVR
# 1456655127      BMW
# 1457203959    NISSA
#               ...
# 8996906906      NIU
# 8996906943    HYUND
# 8996906979    NS/OT
# 8996907017    NS/OT
# 8996907042    HONDA
# Name: Vehicle Make, Length: 3344282, dtype: object

# %%
makes_series = makes_series.groupby(level=1).sum()
makes_series
