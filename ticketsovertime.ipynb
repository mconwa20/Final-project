# %%
#Basic Dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import os
import numpy as np
import pandas as pd
import io

# %%
##Sets Pandas to truncate dataframes
pd.set_option("display.max_rows", 10)

# %%
##Sets Pandas to not truncate dataframes
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
#Input Path
ticketdata = 'Output/deepcleanedmini.csv'

# %%
ticket_df = pd.read_csv(ticketdata)
ticket_df.head()
# Out:
#    Summons Number  Issue Date  Violation Code Vehicle Body Type Vehicle Make  \
# 0      1478409990  01/01/2021              51              SUBN        CHEVR
# 1      1478421186  01/01/2021              20               SDN          KIA
# 2      8556047440  01/01/2021              50              SUBN        HONDA
# 3      8556047464  01/01/2021              71              SUBN         FORD
# 4      8786592798  01/01/2021              71              4DSD        NISSA
#
#    Street Code1  Street Code2  Street Code3  Violation Location  \
# 0         70620         11980             0                46.0
# 1         36230         26610             0                26.0
# 2             0             0             0               115.0
# 3          7990             0             0               115.0
# 4         58730             0             0                90.0
#
#    Violation Precinct Violation Time  Issuer Precinct House Number  \
# ...

# %%
ticket_df
# Out:
#         Summons Number  Issue Date  Violation Code Vehicle Body Type  \
# 0           1478409990  01/01/2021              51              SUBN
# 1           1478421186  01/01/2021              20               SDN
# 2           8556047440  01/01/2021              50              SUBN
# 3           8556047464  01/01/2021              71              SUBN
# 4           8786592798  01/01/2021              71              4DSD
# ...                ...         ...             ...               ...
# 368037      8994356642  03/31/2021              19              4DSD
# 368038      8994356733  03/31/2021              50              4DSD
# 368039      8994356770  03/31/2021              71              SUBN
# 368040      8995200509  03/31/2021              14              UTIL
# 368041      8995200534  03/31/2021              71               TOW
#
#        Vehicle Make  Street Code1  Street Code2  Street Code3  \
# 0             CHEVR         70620         11980             0
# ...

# %%
ticket_df.dtypes
# Out:
# Summons Number          int64
# Issue Date             object
# Violation Code          int64
# Vehicle Body Type      object
# Vehicle Make           object
#                         ...
# House Number           object
# Street Name            object
# Intersecting Street    object
# Vehicle Color          object
# Vehicle Year            int64
# Length: 17, dtype: object

# %%
ticket_df2 = ticket_df.copy()

# %%
ticket_df2
# Out:
#         Summons Number  Issue Date  Violation Code Vehicle Body Type  \
# 0           1478409990  01/01/2021              51              SUBN
# 1           1478421186  01/01/2021              20               SDN
# 2           8556047440  01/01/2021              50              SUBN
# 3           8556047464  01/01/2021              71              SUBN
# 4           8786592798  01/01/2021              71              4DSD
# ...                ...         ...             ...               ...
# 368037      8994356642  03/31/2021              19              4DSD
# 368038      8994356733  03/31/2021              50              4DSD
# 368039      8994356770  03/31/2021              71              SUBN
# 368040      8995200509  03/31/2021              14              UTIL
# 368041      8995200534  03/31/2021              71               TOW
#
#        Vehicle Make  Street Code1  Street Code2  Street Code3  \
# 0             CHEVR         70620         11980             0
# ...

# %%
ticket_df2['Issue Date'] = ticket_df2['Issue Date'].astype('datetime64[ns]')

# %%
ticket_df2
# Out:
#         Summons Number Issue Date  Violation Code Vehicle Body Type  \
# 0           1478409990 2021-01-01              51              SUBN
# 1           1478421186 2021-01-01              20               SDN
# 2           8556047440 2021-01-01              50              SUBN
# 3           8556047464 2021-01-01              71              SUBN
# 4           8786592798 2021-01-01              71              4DSD
# ...                ...        ...             ...               ...
# 368037      8994356642 2021-03-31              19              4DSD
# 368038      8994356733 2021-03-31              50              4DSD
# 368039      8994356770 2021-03-31              71              SUBN
# 368040      8995200509 2021-03-31              14              UTIL
# 368041      8995200534 2021-03-31              71               TOW
#
#        Vehicle Make  Street Code1  Street Code2  Street Code3  \
# 0             CHEVR         70620         11980             0
# ...

# %%
#date_series = ticket_df2[]

# %%
dateseries = pd.Series(ticket_df2['Issue Date'].values)
dateseries
# Out:
# 0        2021-01-01
# 1        2021-01-01
# 2        2021-01-01
# 3        2021-01-01
# 4        2021-01-01
#             ...
# 368037   2021-03-31
# 368038   2021-03-31
# 368039   2021-03-31
# 368040   2021-03-31
# 368041   2021-03-31
# Length: 368042, dtype: datetime64[ns]

# %%
timeseries = pd.Series(ticket_df2['Violation Time'].values)
timeseries
# Out:
# 0         1027A
# 1         0103P
# 2         0440P
# 3         0547P
# 4         1131A
#           ...
# 368037    0306P
# 368038    0345P
# 368039    0405P
# 368040    0830A
# 368041    0846A
# Length: 368042, dtype: object

# %%
df[['First','Last']] = df.Name.str.split(expand=True)
